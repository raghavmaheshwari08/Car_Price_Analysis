# %%
import pandas as pd
df=pd.read_csv("diabetes.csv")
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-778647701.py in <cell line: 0>()
#       1 import pandas as pd
# ----> 2 df=pd.read_csv("diabetes.csv")
#       3 df.head()
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
#Lets create a clean workflow
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OneHotEncoder

# %%
numerical_columns=["Pregnancies","Glucose","BloodPressure","SkinThickness","Insulin","BMI","DiabetesPedigreeFunction","Age"]

# %%
from sklearn.preprocessing import PowerTransformer

# %%
numerical_transformer=Pipeline(steps=[
    ("transformation",PowerTransformer(method="yeo-johnson")),
    ("scaling",StandardScaler())
])

# %%
preprocessor= ColumnTransformer(transformers=[
    ("trf1",numerical_transformer,numerical_columns)
])

# %%
from sklearn.svm import SVC

# %%
clf=Pipeline(steps=[
    ("preprocessing",preprocessor),
    ("Classifier",LogisticRegression())
])

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(df.drop(columns=["Outcome"]),df["Outcome"],test_size=0.2,random_state=42)

# %%
X_train

# %%
y_train

# %%
clf.fit(X_train,y_train)

# %%
y_pred=clf.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3871864176.py in <cell line: 0>()
# ----> 1 y_pred=clf.predict(X_test)
#
# NameError: name 'clf' is not defined

# %%
accuracy_score(y_pred,y_test)

# %%
import scipy.stats as stats
import matplotlib.pyplot as plt

# %%
stats.probplot(df["Glucose"],plot=plt)
plt.show()
df["Glucose"].skew()

# %%
import numpy as np
import seaborn as sns

# %%
ds=pd.read_csv("diabetes.csv")

# %%
sns.distplot(ds["Glucose"])

# %%
sns.distplot(df["Insulin"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3775586177.py in <cell line: 0>()
# ----> 1 sns.distplot(df["Insulin"])
#
# NameError: name 'sns' is not defined

# %%
df["Insulin"]=df["Insulin"].apply(lambda x:x**2)

# %%
sns.distplot(df["BloodPressure"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2063375412.py in <cell line: 0>()
# ----> 1 sns.distplot(df["BloodPressure"])
#
# NameError: name 'sns' is not defined

# %%
df["BloodPressure"]=df["BloodPressure"].apply(lambda x:np.log1p(x))

# %%
sns.distplot(df['BMI'])
df['BMI'].skew()

# %%
sns.distplot(df["Age"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2732350774.py in <cell line: 0>()
# ----> 1 sns.distplot(df["Age"])
#
# NameError: name 'sns' is not defined

# %%
df["Age"]=df["Age"].apply(lambda x: np.log1p(x))

# %%
sns.distplot(df["SkinThickness"])

# %%
df["SkinThickness"]=df["SkinThickness"].apply(lambda x: np.log1p(x))

# %%
sns.distplot(df["SkinThickness"])

# %%
df["SkinThickness"].skew()

# %%
sns.distplot(df["DiabetesPedigreeFunction"])

# %%
df["DiabetesPedigreeFunction"]=df["DiabetesPedigreeFunction"].apply(lambda x: np.log1p(x))

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(df.drop(columns=["Outcome"]),df["Outcome"],stratify=df["Outcome"],test_size=0.2)

# %%
lgr=LogisticRegression()

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
mm= MinMaxScaler()

# %%
X_train=mm.fit_transform(X_train)
X_test=mm.transform(X_test)

# %%
lgr.fit(X_train,y_train)

y_pred=lgr.predict(X_test)
accuracy_score(y_test,y_pred)
